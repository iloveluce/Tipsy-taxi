# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt # module for plotting 

# %matplotlib inline

# %%
taxi = pd.read_csv('master.csv')
print len(taxi)
taxi.head()
# Out:
# 120000
#    Unnamed: 0                       medallion_x  \
# 0           0  515EB6F8BEDB2B17CF1CF3B27B76AA93
# 1           1  6F70DA82F52A1281E4E6646AE996D25A
# 2           2  E8381ABE90A167521E37DFF144BEE70C
# 3           3  DAB668CC77B6E2BCDE421DA934DB2316
# 4           4  DF8A37AE74123C21860C80C8A1EEDA17
#
#                        hack_license vendor_id  rate_code store_and_fwd_flag  \
# 0  A5AFFC8549AF873DEC5889ADE3BE7462       VTS          1                NaN
# 1  4103ADCF50D18CFE25AB616F368A5945       VTS          2                NaN
# 2  0764AFB6DDECA74D776ABE460EE85CAB       VTS          1                NaN
# 3  7043B6B2FFF3160417316401FAE83ACF       VTS          1                NaN
# 4  4045C05F38C2E333B7C212CEC21E4FE8       VTS          1                NaN
#
#        pickup_datetime     dropoff_datetime  passenger_count  \
# 0  2013-01-13 09:36:00  2013-01-13 09:45:00                1
# 1  2013-01-13 06:43:00  2013-01-13 07:03:00                1
# ...
